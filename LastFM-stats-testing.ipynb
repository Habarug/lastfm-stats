# %%
import LastFMStats
import os 
import importlib

# %%
importlib.reload(LastFMStats)

filename = os.path.join('LastFM-exports', 'HabaMad_2023-12-23.csv')
lastfm = LastFMStats.LastFMStats(filename)

# %%
lastfm.plot_WD_distribution()

# %%
lastfm.plot_top_artists_timeline()

# %%
lastfm.plot_top_albums_timeline()

# %%
lastfm.plot_artist_album_distribution(20, 0.03)

# %%
lastfm.plot_stacked_timeline(15)
